# %%
# Importando as Bibiotecas
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
from math import floor

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Ler a imagem

img1 = cv2.imread("/content/drive/MyDrive/Imagens Visao Computacional /Img2.jpg")

# Visualizacao da imagem
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>

# %%
# Verificacao das dimensoes

img1.shape
# Out:
# (480, 640, 3)

# %%
img1.shape[1]*0.5
# Out:
# 320.0

# %%
color = ('red', 'green', 'blue')

# %%
img11 = img1.copy()

# for i in range(int(img11.shape[0]*0.5),(img11.shape[0])):
#   for j in range(img11.shape[1]):
    # red, green, blue = img11[i, j]

for i in range(int(img11.shape[0]*0.6),(img11.shape[0])):
  for j in range(0, img11.shape[1]):
    # Lembrando que 0 = blue; 1 = green; 2 = red

  # Vermelho = Branco
    if img11[i][j][0] > 180 and img11[i][j][1] > 190 and img11[i][j][2] > 200 :
      img11[i,j] = (0, 0,255)

    if img11[i][j][0] > 140 and img11[i][j][1] > 160 and img11[i][j][2] > 160 :
      img11[i,j] = (0, 0,255)

  # Azul = Amarelo
    if img11[i][j][0] < 140 and img11[i][j][1] > 200 and img11[i][j][2] > 210 :
      img11[i,j] = (255, 0,0)

    if img11[i][j][0] < 40 and img11[i][j][1] > 170 and img11[i][j][2] > 210 :
      img11[i,j] = (255, 0,0)

    if img11[i][j][0] < 100 and img11[i][j][1] > 90 and img11[i][j][2] > 130 :
      img11[i,j] = (255, 0,0)

cv2_imshow(img11)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>
